# %%
import celldancer.velocity_estimation as calc_velocity
import pandas as pd 
from plotting import gene as cdpl_gene
from plotting import gene as cdpl_cell
from plotting.colormap import *

# %% [markdown]
# # velocity estimation

# %%
raw_path='/Users/shengyuli/Library/CloudStorage/OneDrive-HoustonMethodist/work/Velocity/data/raw_data/mouse_endo_blood20to25_2000_genes_moment100.csv'
load_raw_data=pd.read_csv(raw_path)
gene_choice=["Blvrb","Phc2","Skap1","Nfkb1","Myo1b","Sulf2","Yipf5","Coro2b","Mllt3","Smarca2","Hba-x","Smim1","Snca"]
result_path = '/Users/shengyuli/Library/CloudStorage/OneDrive-HoustonMethodist/work/Velocity/data/Gastrulation/velocity_result/result_detailcsv/polish/'
brief, load_cellDancer=calc_velocity.train(load_raw_data,gene_choice=gene_choice,result_path=result_path,n_jobs=8)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {}
# --------------------------------------------------------------------------------
# My calculation:   0%|                                    | 0/13 [00:00<?, ?it/s]GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# IPU available: False, using: 0 IPUs
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# GPU available: False, used: False
# IPU available: False, using: 0 IPUs
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# My calculation:   8%|██▏                         | 1/13 [00:06<01:23,  6.93s/it]GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# My calculation:  23%|██████▍                     | 3/13 [00:10<00:26,  2.62s/it]GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# My calculation:  31%|████████▌                   | 4/13 [00:10<00:15,  1.76s/it]GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# My calculation:  38%|██████████▊                 | 5/13 [00:11<00:10,  1.32s/it]GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# My calculation: 100%|███████████████████████████| 13/13 [00:18<00:00,  1.42s/it]

# %%
load_cellDancer
# Out:
#         cellIndex gene_name        s0        u0        s1        u1     alpha  \
# 0               0     Skap1  0.496679  0.092916  0.365329  0.066440  0.014698
# 1               1     Skap1  0.486403  0.244527  0.421972  0.208734  0.110595
# 2               2     Skap1  0.655514  0.246036  0.533556  0.189434  0.068091
# 3               3     Skap1  0.357083  0.016535  0.242648  0.014589  0.009250
# 4               4     Skap1  0.318381  0.036937  0.226399  0.030095  0.014188
# ...           ...       ...       ...       ...       ...       ...       ...
# 160272      12324      Phc2  0.133419  0.034524  0.125732  0.035894  0.056113
# 160273      12325      Phc2  0.096803  0.051354  0.103762  0.050585  0.071912
# 160274      12326      Phc2  0.065688  0.051531  0.078410  0.052955  0.079854
# 160275      12327      Phc2  0.105551  0.070105  0.119532  0.064734  0.081322
# 160276      12328      Phc2  0.090410  0.043348  0.094790  0.044877  0.068983
#
#             beta     gamma      cost       cellID             clusters  \
# 0       0.580751  0.658862  0.078317     cell_363  Blood progenitors 2
# 1       0.553015  0.634158  0.078317     cell_382  Blood progenitors 2
# 2       0.571187  0.651162  0.078317     cell_385  Blood progenitors 2
# 3       0.579008  0.655804  0.078317     cell_393  Blood progenitors 2
# 4       0.570612  0.648377  0.078317     cell_398  Blood progenitors 2
# ...          ...       ...       ...          ...                  ...
# 160272  0.421518  0.250766  0.042125  cell_139318           Erythroid3
# 160273  0.415691  0.253349  0.042125  cell_139321           Erythroid3
# 160274  0.412793  0.253404  0.042125  cell_139326           Erythroid3
# 160275  0.412954  0.257149  0.042125  cell_139327           Erythroid3
# 160276  0.416530  0.251869  0.042125  cell_139330           Erythroid3
#
#         embedding1  embedding2
# 0         3.460521   15.574629
# 1         2.490433   14.971734
# 2         2.351203   15.267069
# 3         5.899098   14.388825
# 4         4.823139   15.374831
# ...            ...         ...
# 160272    8.032358    7.603037
# 160273   10.352904    6.446736
# 160274    9.464873    7.261099
# 160275    9.990495    7.243880
# 160276    8.260699    7.935455
#
# [160277 rows x 14 columns]

# %%
cdpl_gene.velocity_gene(gene_choice[0:3],load_cellDancer,colors=colormap_erythroid,mode='cluster',cluster_annot=True,point_size=30,alpha_inside=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

f = plt.figure(figsize=(20,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
x = np.linspace(0,4,1000)
ax.plot(x, np.sin(x))
ax2.plot(x, np.cos(x), 'r:')

# %% [markdown]
# # gene velocity

# %%
gene_choice=["Blvrb","Phc2","Skap1","Nfkb1","Myo1b","Sulf2","Yipf5","Coro2b","Mllt3","Smarca2","Hba-x","Smim1","Snca"]

raw_data_path = "/Users/shengyuli/Library/CloudStorage/OneDrive-HoustonMethodist/work/Velocity/data/raw_data/mouse_endo_blood20to25_2000_genes_moment100.csv"
load_raw_data = pd.read_csv(raw_data_path)
load_cellDancer=pd.read_csv('/Users/shengyuli/Library/CloudStorage/OneDrive-HoustonMethodist/work/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000genes_with_bin_and_smooth/combined_detail/combined_detail.csv')

# %%
cdpl_gene.velocity_gene(gene_choice,load_cellDancer,colors=colormap_erythroid,mode='cluster',cluster_annot=True,point_size=30,alpha_inside=1)

# %% [markdown]
# # cell velocity

# %%
cdpl_cell.scatter_cell(load_raw_data,load_cellDancer,n_neighbors=10,add_amt_gene=2000, save_path=output_path, save_csv=True, gene_list=None, colors=colormap_erythroid,step=(100,100),mode='gene',pca_n_components=None,file_name_additional_info=file_name_additional_info,umap_n=umap_n,transfer_mode='power10',umap_n_components=umap_n_components,min_mass=15,grid_steps=(20, 20),custom_xlim=[-6,13],custom_ylim=[2,16],alpha_inside=0.3,use_downsampling= True)

# %%
vpl.velocity_cell_map_curve(load_raw_data,load_cellDancer,n_neighbors=10,add_amt_gene=2000, save_path=output_path, save_csv=True, gene_list=None, colors=colormap_erythroid,step=(100,100),mode='gene',pca_n_components=None,file_name_additional_info=file_name_additional_info,umap_n=umap_n,transfer_mode='power10',umap_n_components=umap_n_components,min_mass=15,grid_steps=(20, 20),custom_xlim=[-6,13],custom_ylim=[2,16],alpha_inside=0.3,use_downsampling= True)
# Out:
# ------n_neighbors10
# ------add_amt_gene2000
# neighbors
# tranfer mode: power10
# using gene mode
# (2000, 12329)
# (2000, 12329)
# /Users/wanglab/Documents/ShengyuLi/Velocity/bin/cellDancer-development_20220128/src/get_embedding.py:50: RuntimeWarning: invalid value encountered in true_divide
#   np.sqrt(np.dot(ematrix_ss[:, None], vmatrix_ss[None]))
# 4.1930088182233645
# 0.6906665710493576
# 0.16471860685043885

# %%
buffer = StringIO.StringIO()
df.to_csv(buffer)
print buffer.getvalue()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0m/7mylm3gs5hj8zfvd2hbr8ntc0000gq/T/ipykernel_36653/2365930844.py in <module>
# ----> 1 with tempfile.NamedTemporaryFile as temp:
#       2     load_raw_data.to_csv(temp.name)
#
# NameError: name 'tempfile' is not defined
