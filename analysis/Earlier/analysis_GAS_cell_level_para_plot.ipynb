# %%
# https://github.com/velocyto-team/velocyto-notebooks/blob/master/python/DentateGyrus.ipynb

import pandas as pd
from velocity_plot import velocity_plot as vpl
import pandas as pd
import os

# %%
# load raw
raw_data_path = "/Users/wanglab/Documents/ShengyuLi/Velocity/data/raw_data/mouse_endo_blood20to25_2000_genes_moment100.csv"
load_raw_data = pd.read_csv(raw_data_path)

# combine detail
detail_result_path = '/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes'
path_name_after_no='_all_geneepoch200check_n10Lr0.001C2cf0.3Downneighbors0_200_200Ratio0.125N30OAdamtraceR0.0corrcoefR0.0/detail_e200.csv'
load_cellDancer=pd.DataFrame()
for i in range(1,11):
    detail_path=os.path.join(detail_result_path,(str(i)+path_name_after_no))
    detail=pd.read_csv(detail_path)
    load_cellDancer=load_cellDancer.append(detail)
# load_cellDancer_bkup=load_cellDancer.copy()

# define output path

# %%
save_path = '/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes/cell_level_para'
# color_map_list=[color_map1,color_map1,color_map1,color_map4,color_map4]
para_list=['alpha','beta','gamma','s0','u0']
gene_choice=['Smim1','Hba-x','Snca']

# save_path=None

# plot with fixed clusters
# cluster_choice=['nIPC']
# vpl.cell_level_para_plot(read_raw_data,detail,gene_choice,para_list,cluster_choice=cluster_choice,save_path=save_path,pointsize=50,alpha=0.3)

# regular plot
vpl.cell_level_para_plot(load_raw_data,load_cellDancer,gene_choice,para_list,save_path=save_path)

# %%
########### splicing β and degradation γ top 10% genes to do enrichment analysis
load_cellDancer
# Out:
#          Unnamed: 0 gene_name        s0        u0        s1        u1  \
# 0                 0       Hk1  0.311147  0.023061  0.343293  0.013184
# 1                 1       Hk1  0.220703  0.043649  0.281857  0.025953
# 2                 2       Hk1  0.300765  0.046840  0.367109  0.027165
# 3                 3       Hk1  0.575079  0.037984  0.630540  0.020755
# 4                 4       Hk1  0.452859  0.039503  0.509815  0.022012
# ...             ...       ...       ...       ...       ...       ...
# 2465795       12324   Syncrip  0.400352  0.079564  0.411125  0.115723
# 2465796       12325   Syncrip  0.260445  0.121604  0.325618  0.142444
# 2465797       12326   Syncrip  0.309220  0.125791  0.371167  0.146414
# 2465798       12327   Syncrip  0.282135  0.106819  0.331271  0.132887
# 2465799       12328   Syncrip  0.304782  0.125564  0.367172  0.146149
#
#             alpha      beta     gamma      cost
# 0        0.003450  0.237919  0.015017  0.118257
# ...

# %%
beta_gamma=load_cellDancer.groupby('gene_name')[['beta','gamma']].mean()

# %%
import numpy as np
beta_des=beta_gamma.sort_values(by=['beta'],ascending = False)
beta_des_top10per=beta_des.index[0:int(len(beta_des)/10)]

beta_des_top10per_np=np.array(beta_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes/cell_level_para/beta_des_top10per.txt',beta_des_top10per_np, fmt='%s')

beta_des_top10per_np=np.array(beta_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes/cell_level_para/beta_des_top10per.txt',beta_des_top10per_np, fmt='%s')

# %%
gamma_des=beta_gamma.sort_values(by=['gamma'],ascending = False)
gamma_des_top10per=gamma_des.index[0:int(len(gamma_des)/10)]

gamma_des_top10per_np=np.array(gamma_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes/cell_level_para/gamma_des_top10per.txt',gamma_des_top10per, fmt='%s')

# %%
# load housekeeping genes
