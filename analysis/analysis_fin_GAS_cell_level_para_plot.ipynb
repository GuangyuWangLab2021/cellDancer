# %%
# https://github.com/velocyto-team/velocyto-notebooks/blob/master/python/DentateGyrus.ipynb

import pandas as pd
from velocity_plot import velocity_plot as vpl
import pandas as pd
import os

# %%
# load raw
raw_data_path = "/Users/wanglab/Documents/ShengyuLi/Velocity/data/raw_data/mouse_endo_blood20to25_2000_genes_moment100.csv"
load_raw_data = pd.read_csv(raw_data_path)

# combine detail
load_cellDancer=load_cellDancer=pd.read_csv('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes_v2_smooth_bin/2000genes_with_bin_and_smooth/combined_detail/combined_detail.csv')

# define output path

# %%
save_path = '/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes_v2_smooth_bin/2000genes_with_bin_and_smooth/cell_level_para'
# color_map_list=[color_map1,color_map1,color_map1,color_map4,color_map4]
para_list=['alpha','beta','gamma','s0','u0']
gene_choice=['Smim1','Hba-x','Snca']

#save_path=None

# plot with fixed clusters
# cluster_choice=['nIPC']
# vpl.cell_level_para_plot(read_raw_data,detail,gene_choice,para_list,cluster_choice=cluster_choice,save_path=save_path,pointsize=50,alpha=0.3)

# regular plot
vpl.cell_level_para_plot(load_raw_data,load_cellDancer,gene_choice,para_list,save_path=save_path)

# %%
# TODO : DEL OUTLIER

# %% [markdown]
# # NOT KEEP. splicing β and degradation γ top 10% genes to do enrichment analysis

# %%
load_cellDancer
# Out:
#           cellIndex      gene_name        s0        u0        s1        u1  \
# 0                 0  2810025M15Rik  1.515440  0.000000  1.514860  0.000022
# 1                 1  2810025M15Rik  1.574459  0.000000  1.573860  0.000022
# 2                 2  2810025M15Rik  1.744201  0.000000  1.743548  0.000020
# 3                 3  2810025M15Rik  1.332406  0.000000  1.331888  0.000024
# 4                 4  2810025M15Rik  1.261786  0.000000  1.261292  0.000025
# ...             ...            ...       ...       ...       ...       ...
# 24657995      12324          Zrsr2  0.255452  0.030816  0.323642  0.022484
# 24657996      12325          Zrsr2  0.204272  0.049630  0.322781  0.036203
# 24657997      12326          Zrsr2  0.230350  0.050146  0.349145  0.036532
# 24657998      12327          Zrsr2  0.236227  0.052799  0.361591  0.038445
# 24657999      12328          Zrsr2  0.234467  0.057909  0.372997  0.042155
#
# ...

# %%
beta_gamma=load_cellDancer.groupby('gene_name')[['beta','gamma']].mean()

# %%
import numpy as np
beta_des=beta_gamma.sort_values(by=['beta'],ascending = False)
beta_des_top10per=beta_des.index[0:int(len(beta_des)/10)]

beta_des_top10per_np=np.array(beta_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes_v2_smooth_bin/2000genes_with_bin_and_smooth/cell_level_para/beta_des_top10per.txt',beta_des_top10per_np, fmt='%s')

beta_des_top10per_np=np.array(beta_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes_v2_smooth_bin/2000genes_with_bin_and_smooth/cell_level_para/beta_des_top10per.txt',beta_des_top10per_np, fmt='%s')

# %%
gamma_des=beta_gamma.sort_values(by=['gamma'],ascending = False)
gamma_des_top10per=gamma_des.index[0:int(len(gamma_des)/10)]

gamma_des_top10per_np=np.array(gamma_des_top10per)
np.savetxt('/Users/wanglab/Documents/ShengyuLi/Velocity/data/Gastrulation/velocity_result/result_detailcsv/2000_genes_v2_smooth_bin/2000genes_with_bin_and_smooth/cell_level_para/gamma_des_top10per.txt',gamma_des_top10per, fmt='%s')

# %%
# load housekeeping genes
