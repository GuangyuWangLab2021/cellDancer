# %%
import os
import glob
import random
import time
import sys
import importlib

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# import from absolute directory
srcdir = '/Users/pengzhizhang/cellDancer/src'
sys.path.append(srcdir) 
from pseudo_time import *

# %% [markdown]
# # Load up all the input and process ~ 4 mins

# %%
data_path = os.path.join(srcdir, "/Users/pengzhizhang/pseudotime/data/pancreas")
detail_result_path = os.path.join(data_path, "velocity_result")
output_path = os.path.join(data_path, "pseudotime_result")
os.makedirs(output_path, exist_ok=True)
raw_data_path = os.path.join(data_path, "raw_data")

raw_data_file = os.path.join(raw_data_path, "scv_data_full.csv")


# Fixed parameters
n_neighbors=100
step=(60,60)

start_time = time.time()
__ = load_velocity(raw_data_file, detail_result_path, n_neighbors, step)
load_cellDancer = __[0]
embedding = __[1]
sampling_ixs = __[2]
velocity_embedding = __[3]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# neighbors
# tranfer mode: None
# None
# using gene mode
# (2000, 3696)
# (2000, 3696)
# /Users/pengzhizhang/cellDancer/src/get_embedding.py:50: RuntimeWarning: invalid value encountered in true_divide
#   np.sqrt(np.dot(ematrix_ss[:, None], vmatrix_ss[None]))
# --- 287.5312011241913 seconds ---

# %%
importlib.reload(sys.modules["pseudo_time"])
from pseudo_time import *


dt = 0.001
t_total = 10000
n_repeats = 10

grid = (20,20)
cell_time = pseudo_time(load_cellDancer,
    embedding, velocity_embedding, 
    sampling_ixs, step,
    grid, dt, t_total, n_repeats, 
    output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2p/2j0f_d_13815dk9jyzwnfl540000gp/T/ipykernel_47923/559704799.py in <module>
#      12     sampling_ixs, step,
#      13     grid, dt, t_total, n_repeats,
# ---> 14     output_path)
#
# ~/cellDancer/src/pseudo_time.py in pseudo_time(load_cellDancer, embedding, velocity_embedding, sampling_ixs, downsample_step, grid, dt, t_total, n_repeats, output_path)
#      64                         off_cell_init=False,
#      65                         n_repeats = n_repeats,
# ---> 66                         n_jobs = mp.cpu_count()-1)
#      67
#      68     newPaths = truncate_end_state_stuttering(paths, cell_embedding, PLOT=False)
#
# ~/cellDancer/src/diffusion.py in run_diffusion(cell_embedding, vel, grid_density, dt, t_total, eps, off_cell_init, init_cell, n_repeats, n_jobs)
#     522
#     523     with mp.Pool(n_jobs) as pool:
# --> 524         paths = pool.starmap(diffusion_off_grid_wallbound, TASKS)
#     525     return np.array(paths, dtype=object)
#     526
#
# ~/miniconda3/envs/cellDancer/lib/python3.7/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     274         `func` and (a, b) becomes func(a, b).
#     275         '''
# --> 276         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     277
#     278     def starmap_async(self, func, iterable, chunksize=None, callback=None,
#
# ~/miniconda3/envs/cellDancer/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/miniconda3/envs/cellDancer/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/miniconda3/envs/cellDancer/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/envs/cellDancer/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
