# %%
# 	1. The program can directly right click and "run Run Current File in interactive Window"

# %%
#   2. Parameters that could be adjusted

# %%
use_all_gene=False # Fit all genes or genes in gene_choice
plot_trigger=True # Plot Velocity and Validation_epoch results of each gene or not
data_source="denGyr" #["scv","denGyr"] # "scv" - Nature paper; "denGyr" - NC paper
platform="local" #["hpc","local"]
#############################################
###########     Set Parameters   ############
#############################################
if platform=="local":
    model_dir='../../data/model2'
    epoches=[0,5,10,50,100,200,300,400,500]
    epoches=[0,10]
    num_jobs=8
    learning_rate=0.1
    cost_version=1 # choose from [1,2]; 1 means cost1; 2 means the combination of cost1&2
    cost1_ratio=0.8 ####### The sum of cost1 and cost2 is 1
    cost2_cutoff=0.3 
    downsample_method= "neighbors" # choose from ["neighbors","inverse","circle"]
    downsample_target_amount=500 # valid for ["inverse","circle"]
    step_i=30 # valid for ["neighbors"] #step 250 will got 4000 from den_gyr data 
    step_j=30 # valid for ["neighbors"] #step 250 will got 4000 from den_gyr data 
    sampling_ratio=0.125 # default 0.5 # the sampling amount inside the fitting
    n_neighbors=20 # neighbors calculation inside the network # default 30
    optimizer="SGD" #["SGD","Adam"]

# %%
# 3.   The input (scv_data.csv and denGyr.csv) is located at "data" folder under current python working path; 
raw_data_path
# Out:
# 'data/denGyr.csv'

# %%
# 4.   The output detail.csv, brief.csv, velocity scatter plots, and velocity plots are located at "save_path" and "save_path_validation" parameter

# %%
save_path
# Out:
# 'output/detailcsv/adj_e/denGyrLr0.1Costv1C1r0.8C2cf0.3Downneighbors500_30_30Ratio0.125N20OSGD/Tmem163_e10.pdf'

# %%
save_path_validation
# Out:
# 'output/detailcsv/adj_e/denGyrLr0.1Costv1C1r0.8C2cf0.3Downneighbors500_30_30Ratio0.125N20OSGD/Tmem163_validation_e10.pdf'
